# %%
# !pip install ydata-profiling
# Out:
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# ...
#   Using cached numpy-2.3.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached numba-0.62.1-cp313-cp313-win_amd64.whl.metadata (2.9 kB)
# ...
#   Using cached llvmlite-0.45.1-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 2.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.0 MB 2.7 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.0 MB 2.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.0 MB 2.7 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.0 MB 2.7 MB/s eta 0:00:02
# ...

# %%
from ydata_profiling import ProfileReport
import pandas as pd

dataset=pd.read_excel('flight_price.xlsx')

# %%
dataset
# Out:
#            Airline Date_of_Journey    Source  ... Total_Stops Additional_Info  Price
# 0           IndiGo      24/03/2019  Banglore  ...    non-stop         No info   3897
# 1        Air India       1/05/2019   Kolkata  ...     2 stops         No info   7662
# 2      Jet Airways       9/06/2019     Delhi  ...     2 stops         No info  13882
# 3           IndiGo      12/05/2019   Kolkata  ...      1 stop         No info   6218
# 4           IndiGo      01/03/2019  Banglore  ...      1 stop         No info  13302
# ...            ...             ...       ...  ...         ...             ...    ...
# 10678     Air Asia       9/04/2019   Kolkata  ...    non-stop         No info   4107
# 10679    Air India      27/04/2019   Kolkata  ...    non-stop         No info   4145
# 10680  Jet Airways      27/04/2019  Banglore  ...    non-stop         No info   7229
# 10681      Vistara      01/03/2019  Banglore  ...    non-stop         No info  12648
# ...

# %%
report=ProfileReport(dataset,title='Flight Data Report')

# %%
report.to_file('report.html')
# Out:
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 108.81it/s]

# %%
# !pip install ipywidgets
# Out:
# ...
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ---------------------------------- ----- 786.4/914.9 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 914.9/914.9 kB 1.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 891.8 kB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.2 MB 891.8 kB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.2 MB 733.7 kB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.2 MB 738.6 kB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.2 MB 738.6 kB/s eta 0:00:02
# ...

# %%
report.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-01-15 07:20:17.494317&quot; name=date&gt;&lt;title&gt;Flight Data Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
df=pd.read_csv('cleaned_dataset.csv')
df.head()
# Out:
#    Total_Stops  Price  ...  Additional_Info_No info  Additional_Info_Red-eye flight
# 0            0   3897  ...                      1.0                             0.0
# 1            2   7662  ...                      1.0                             0.0
# 2            2  13882  ...                      1.0                             0.0
# 3            1   6218  ...                      1.0                             0.0
# 4            1  13302  ...                      1.0                             0.0
#
# [5 rows x 44 columns]

# %%
clean_report=ProfileReport(df,title='Cleaned Flight Data')
clean_report.to_notebook_iframe()
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-01-15 07:27:16.880302&quot; name=date&gt;&lt;title&gt;Cleaned Flight Data&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
