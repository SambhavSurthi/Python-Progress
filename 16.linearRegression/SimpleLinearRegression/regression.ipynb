# %% [markdown]
# ### Salary Prediction Using Experience Using Simple Linear Regression

# %%
# Split the Data Into Training and Testing data

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.60,random_state=42)
#We Need Standardize the values. As Both the units are different

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

X_test=scaler.transform(X_test)

# Train the model
regression=LinearRegression(n_jobs=-1)

regression.fit(X_train,y_train)

# Printing Coefficient and intecept

print('Coefficient: ',regression.coef_)
print('Intercept:',regression.intercept_)

plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# Prediction For Test Data
y_predicted=regression.predict(X_test)

print(mean_squared_error(y_test,y_predicted))
print(mean_absolute_error(y_test,y_predicted))
print(root_mean_squared_error(y_test,y_predicted))
print(r2_score(y_test,y_predicted))

print(regression.predict(scaler.transform([[1.5]])))

# %%
# Import all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score

# %%
# Read The Dataset
dataset=pd.read_csv('Salary_dataset.csv')

# %%
dataset
# Out:
#     YearsExperience  Salary
# 0               1.2   39344
# 1               1.4   46206
# 2               1.6   37732
# 3               2.1   43526
# 4               2.3   39892
# 5               3.0   56643
# 6               3.1   60151
# 7               3.3   54446
# 8               3.3   64446
# 9               3.8   57190
# 10              4.0   63219
# 11              4.1   55795
# 12              4.1   56958
# 13              4.2   57082
# 14              4.6   61112
# 15              5.0   67939
# 16              5.2   66030
# 17              5.4   83089
# 18              6.0   81364
# 19              6.1   93941
# 20              6.9   91739
# 21              7.2   98274
# 22              8.0  101303
# 23              8.3  113813
# 24              8.8  109432
# 25              9.1  105583
# 26              9.6  116970
# 27              9.7  112636
# 28             10.4  122392
# 29             10.6  121873

# %%
# Divide the Dataset into Independent[2D Array/Dataframe] and Dependent featuresss[1DArray/Series]
X=dataset[['YearsExperience']]
y=dataset['Salary']

# %%
X
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
type(X)
X.shape
# Out:
# (30, 1)

# %%
y
# Out:
# 0      39344
# 1      46206
# 2      37732
# 3      43526
# 4      39892
# 5      56643
# 6      60151
# 7      54446
# 8      64446
# 9      57190
# 10     63219
# 11     55795
# 12     56958
# 13     57082
# 14     61112
# 15     67939
# 16     66030
# 17     83089
# 18     81364
# 19     93941
# 20     91739
# 21     98274
# 22    101303
# 23    113813
# 24    109432
# 25    105583
# 26    116970
# 27    112636
# 28    122392
# 29    121873
# Name: Salary, dtype: int64

# %%
type(y)
y.shape
# Out:
# (30,)

# %%
# Scatter Plot for the series
plt.scatter(x=X,y=y)

# %%
# Check the correlation
dataset.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.pairplot(data=dataset)

# %%
# Split the Data Into Training and Testing data

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.60,random_state=42)

# %%
#We Need Standardize the values. As Both the units are different

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.16090487],
#        [-1.50346696],
#        [ 0.43771823],
#        [ 1.35121714],
#        [-0.01903123],
#        [ 1.73184169],
#        [ 0.32353086],
#        [-1.0467175 ],
#        [-0.78028032],
#        [-0.55190559],
#        [ 0.01903123],
#        [-1.12284241]])

# %%
X_test
# Out:
# array([[ 1.38927959],
#        [-0.39965577],
#        [ 0.85640523],
#        [-0.24740596],
#        [-1.0467175 ],
#        [-0.85640523],
#        [ 1.65571678],
#        [ 1.0467175 ],
#        [-0.74221787],
#        [-1.84602905],
#        [-1.42734205],
#        [-0.32353086],
#        [-1.16090487],
#        [-0.70415541],
#        [-0.74221787],
#        [ 0.74221787],
#        [-1.76990414],
#        [-1.69377923]])

# %%
# Train the model
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
# Printing Coefficient and intecept

print('Coefficient: ',regression.coef_)
print('Intercept:',regression.intercept_)
# Out:
# Coefficient:  [24299.86083402]
# Intercept: 82683.16666666667

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %%
# Prediction For Test Data
y_predicted=regression.predict(X_test)

# %%
y_predicted
# Out:
# array([116442.46746348,  72971.58698539, 103493.69455511,  76671.23638778,
#         57248.07702523,  61872.63877822, 122916.85391766, 108118.2563081 ,
#         64647.37583001,  37824.91766268,  47998.95351926,  74821.41168659,
#         54473.33997344,  65572.28818061,  64647.37583001, 100718.95750332,
#         39674.74236388,  41524.56706507])

# %%
print(mean_squared_error(y_test,y_predicted))
print(mean_absolute_error(y_test,y_predicted))
print(root_mean_squared_error(y_test,y_predicted))
# Out:
# 37789731.97334374
# 5323.46097093109
# 6147.33535552956

# %%
print(r2_score(y_test,y_predicted))
score=r2_score(y_test,y_predicted)
# Out:
# 0.9497286449627115

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.9465866852728809

# %%
print(regression.predict(scaler.transform([[0]])))
# Out:
# [26725.96945551]
# d:\Udemy\DataScience\Python\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Liner Regression Using OLS

# %%
# !pip install statsmodels
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.5 MB 7.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.5 MB 7.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.5 MB 9.0 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.5 MB 7.6 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 5.2 MB/s  0:00:02
# ...
#
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
# ...

# %%
import statsmodels.api as sm

# %%
X_train
# Out:
# array([[ 1.16090487],
#        [-1.50346696],
#        [ 0.43771823],
#        [ 1.35121714],
#        [-0.01903123],
#        [ 1.73184169],
#        [ 0.32353086],
#        [-1.0467175 ],
#        [-0.78028032],
#        [-0.55190559],
#        [ 0.01903123],
#        [-1.12284241]])

# %%
y_train
# Out:
# 25    105583
# 3      43526
# 21     98274
# 26    116970
# 18     81364
# 29    121873
# 20     91739
# 7      54446
# 10     63219
# 14     61112
# 19     93941
# 6      60151
# Name: Salary, dtype: int64

# %%
model=sm.OLS(y_train,X_train).fit()

# %%
prediction=model.predict(X_test)

# %%
prediction
# Out:
# array([ 33759.30079681,  -9711.57968127,  20810.52788845,  -6011.93027888,
#        -25435.08964143, -20810.52788845,  40233.687251  ,  25435.08964143,
#        -18035.79083665, -44858.24900398, -34684.21314741,  -7861.75498008,
#        -28209.82669323, -17110.87848606, -18035.79083665,  18035.79083665,
#        -43008.42430279, -41158.59960159])

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.079
# Model:                            OLS   Adj. R-squared (uncentered):             -0.004
# Method:                 Least Squares   F-statistic:                             0.9468
# Date:                Mon, 12 Jan 2026   Prob (F-statistic):                       0.351
# Time:                        13:47:06   Log-Likelihood:                         -152.92
# No. Observations:                  12   AIC:                                      307.8
# Df Residuals:                      11   BIC:                                      308.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
