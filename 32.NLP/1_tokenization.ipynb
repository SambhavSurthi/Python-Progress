# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in D:\Udemy\DataScience\ML-DL-NLP\venv\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in D:\Udemy\DataScience\ML-DL-NLP\venv\Lib\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.2.19-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in D:\Udemy\DataScience\ML-DL-NLP\venv\Lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in D:\Udemy\DataScience\ML-DL-NLP\venv\Lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --------------------------- ------------ 1.0/1.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 7.0 MB/s  0:00:00
# Downloading regex-2026.2.19-cp313-cp313-win_amd64.whl (277 kB)
# Installing collected packages: regex, nltk
#
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    ---------------------------------------- 2/2 [nltk]
#
# Successfully installed nltk-3.9.2 regex-2026.2.19

# %%
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize,wordpunct_tokenize,TreebankWordTokenizer

# %%
corpus='''
Technology has transformed the way people live, work, and communicate. Over the past two decades, digital platforms have reshaped industries, enabling businesses to operate at a global scale. Remote collaboration tools allow teams to work across continents, while cloud computing provides scalable infrastructure for startups and enterprises alike.

Artificial intelligence is becoming a central component of modern systems. From recommendation engines to autonomous vehicles, machine learning models are used to analyze patterns, make predictions, and automate decision-making processes. As these systems grow more advanced, ethical considerations such as fairness, transparency, and accountability become increasingly important.

Education is also evolving rapidly. Online learning platforms provide access to knowledge for millions of learners worldwide. Personalized learning systems adapt to individual student needs, offering tailored feedback and adaptive assessments. However, access to reliable internet and digital devices remains uneven, creating disparities in educational opportunities.

Climate change presents one of the most pressing challenges of our time. Governments, corporations, and communities are investing in renewable energy solutions, sustainable agriculture, and carbon reduction strategies. Innovation in battery storage, electric vehicles, and smart grids plays a critical role in reducing greenhouse gas emissions.

Healthcare is benefiting from advances in biotechnology and data science. Wearable devices track vital signs in real time, enabling proactive health monitoring. Predictive analytics assists physicians in diagnosing diseases earlier and developing targeted treatment plans. At the same time, data privacy and regulatory compliance remain essential considerations.

Urbanization continues to shape economic development. Smart cities leverage sensors, IoT networks, and data analytics to improve transportation systems, reduce energy consumption, and enhance public safety. As populations grow, sustainable infrastructure planning becomes increasingly vital.

The future of work is being redefined by automation and digital transformation. While some roles may become obsolete, new opportunities emerge in fields such as data science, cybersecurity, and AI engineering. Continuous learning and adaptability are crucial for professionals navigating this changing landscape.


'''

# %%
print(corpus)
# Out:
# Technology has transformed the way people live, work, and communicate. Over the past two decades, digital platforms have reshaped industries, enabling businesses to operate at a global scale. Remote collaboration tools allow teams to work across continents, while cloud computing provides scalable infrastructure for startups and enterprises alike.
#
# Artificial intelligence is becoming a central component of modern systems. From recommendation engines to autonomous vehicles, machine learning models are used to analyze patterns, make predictions, and automate decision-making processes. As these systems grow more advanced, ethical considerations such as fairness, transparency, and accountability become increasingly important.
#
# Education is also evolving rapidly. Online learning platforms provide access to knowledge for millions of learners worldwide. Personalized learning systems adapt to individual student needs, offering tailored feedback and adaptive assessments. However, access to reliable internet and digital devices remains uneven, creating disparities in educational opportunities.
#
# Climate change presents one of the most pressing challenges of our time. Governments, corporations, and communities are investing in renewable energy solutions, sustainable agriculture, and carbon reduction strategies. Innovation in battery storage, electric vehicles, and smart grids plays a critical role in reducing greenhouse gas emissions.
#
# Healthcare is benefiting from advances in biotechnology and data science. Wearable devices track vital signs in real time, enabling proactive health monitoring. Predictive analytics assists physicians in diagnosing diseases earlier and developing targeted treatment plans. At the same time, data privacy and regulatory compliance remain essential considerations.
#
# Urbanization continues to shape economic development. Smart cities leverage sensors, IoT networks, and data analytics to improve transportation systems, reduce energy consumption, and enhance public safety. As populations grow, sustainable infrastructure planning becomes increasingly vital.
#
# The future of work is being redefined by automation and digital transformation. While some roles may become obsolete, new opportunities emerge in fields such as data science, cybersecurity, and AI engineering. Continuous learning and adaptability are crucial for professionals navigating this changing landscape.

# %%
documents=sent_tokenize(corpus)

# %%
documents
# Out:
# ['\nTechnology has transformed the way people live, work, and communicate.',
#  'Over the past two decades, digital platforms have reshaped industries, enabling businesses to operate at a global scale.',
#  'Remote collaboration tools allow teams to work across continents, while cloud computing provides scalable infrastructure for startups and enterprises alike.',
#  'Artificial intelligence is becoming a central component of modern systems.',
#  'From recommendation engines to autonomous vehicles, machine learning models are used to analyze patterns, make predictions, and automate decision-making processes.',
#  'As these systems grow more advanced, ethical considerations such as fairness, transparency, and accountability become increasingly important.',
#  'Education is also evolving rapidly.',
#  'Online learning platforms provide access to knowledge for millions of learners worldwide.',
#  'Personalized learning systems adapt to individual student needs, offering tailored feedback and adaptive assessments.',
#  'However, access to reliable internet and digital devices remains uneven, creating disparities in educational opportunities.',
#  'Climate change presents one of the most pressing challenges of our time.',
#  'Governments, corporations, and communities are investing in renewable energy solutions, sustainable agriculture, and carbon reduction strategies.',
#  'Innovation in battery storage, electric vehicles, and smart grids plays a critical role in reducing greenhouse gas emissions.',
#  'Healthcare is benefiting from advances in biotechnology and data science.',
#  'Wearable devices track vital signs in real time, enabling proactive health monitoring.',
#  'Predictive analytics assists physicians in diagnosing diseases earlier and developing targeted treatment plans.',
#  'At the same time, data privacy and regulatory compliance remain essential considerations.',
#  'Urbanization continues to shape economic development.',
#  'Smart cities leverage sensors, IoT networks, and data analytics to improve transportation systems, reduce energy consumption, and enhance public safety.',
#  'As populations grow, sustainable infrastructure planning becomes increasingly vital.',
#  'The future of work is being redefined by automation and digital transformation.',
#  'While some roles may become obsolete, new opportunities emerge in fields such as data science, cybersecurity, and AI engineering.',
#  'Continuous learning and adaptability are crucial for professionals navigating this changing landscape.']

# %%
for words in documents:
    word=word_tokenize(words)
    print(word)
# Out:
# ['Technology', 'has', 'transformed', 'the', 'way', 'people', 'live', ',', 'work', ',', 'and', 'communicate', '.']
# ['Over', 'the', 'past', 'two', 'decades', ',', 'digital', 'platforms', 'have', 'reshaped', 'industries', ',', 'enabling', 'businesses', 'to', 'operate', 'at', 'a', 'global', 'scale', '.']
# ['Remote', 'collaboration', 'tools', 'allow', 'teams', 'to', 'work', 'across', 'continents', ',', 'while', 'cloud', 'computing', 'provides', 'scalable', 'infrastructure', 'for', 'startups', 'and', 'enterprises', 'alike', '.']
# ['Artificial', 'intelligence', 'is', 'becoming', 'a', 'central', 'component', 'of', 'modern', 'systems', '.']
# ['From', 'recommendation', 'engines', 'to', 'autonomous', 'vehicles', ',', 'machine', 'learning', 'models', 'are', 'used', 'to', 'analyze', 'patterns', ',', 'make', 'predictions', ',', 'and', 'automate', 'decision-making', 'processes', '.']
# ['As', 'these', 'systems', 'grow', 'more', 'advanced', ',', 'ethical', 'considerations', 'such', 'as', 'fairness', ',', 'transparency', ',', 'and', 'accountability', 'become', 'increasingly', 'important', '.']
# ['Education', 'is', 'also', 'evolving', 'rapidly', '.']
# ['Online', 'learning', 'platforms', 'provide', 'access', 'to', 'knowledge', 'for', 'millions', 'of', 'learners', 'worldwide', '.']
# ['Personalized', 'learning', 'systems', 'adapt', 'to', 'individual', 'student', 'needs', ',', 'offering', 'tailored', 'feedback', 'and', 'adaptive', 'assessments', '.']
# ['However', ',', 'access', 'to', 'reliable', 'internet', 'and', 'digital', 'devices', 'remains', 'uneven', ',', 'creating', 'disparities', 'in', 'educational', 'opportunities', '.']
# ['Climate', 'change', 'presents', 'one', 'of', 'the', 'most', 'pressing', 'challenges', 'of', 'our', 'time', '.']
# ['Governments', ',', 'corporations', ',', 'and', 'communities', 'are', 'investing', 'in', 'renewable', 'energy', 'solutions', ',', 'sustainable', 'agriculture', ',', 'and', 'carbon', 'reduction', 'strategies', '.']
# ['Innovation', 'in', 'battery', 'storage', ',', 'electric', 'vehicles', ',', 'and', 'smart', 'grids', 'plays', 'a', 'critical', 'role', 'in', 'reducing', 'greenhouse', 'gas', 'emissions', '.']
# ['Healthcare', 'is', 'benefiting', 'from', 'advances', 'in', 'biotechnology', 'and', 'data', 'science', '.']
# ['Wearable', 'devices', 'track', 'vital', 'signs', 'in', 'real', 'time', ',', 'enabling', 'proactive', 'health', 'monitoring', '.']
# ['Predictive', 'analytics', 'assists', 'physicians', 'in', 'diagnosing', 'diseases', 'earlier', 'and', 'developing', 'targeted', 'treatment', 'plans', '.']
# ['At', 'the', 'same', 'time', ',', 'data', 'privacy', 'and', 'regulatory', 'compliance', 'remain', 'essential', 'considerations', '.']
# ['Urbanization', 'continues', 'to', 'shape', 'economic', 'development', '.']
# ['Smart', 'cities', 'leverage', 'sensors', ',', 'IoT', 'networks', ',', 'and', 'data', 'analytics', 'to', 'improve', 'transportation', 'systems', ',', 'reduce', 'energy', 'consumption', ',', 'and', 'enhance', 'public', 'safety', '.']
# ['As', 'populations', 'grow', ',', 'sustainable', 'infrastructure', 'planning', 'becomes', 'increasingly', 'vital', '.']
# ['The', 'future', 'of', 'work', 'is', 'being', 'redefined', 'by', 'automation', 'and', 'digital', 'transformation', '.']
# ['While', 'some', 'roles', 'may', 'become', 'obsolete', ',', 'new', 'opportunities', 'emerge', 'in', 'fields', 'such', 'as', 'data', 'science', ',', 'cybersecurity', ',', 'and', 'AI', 'engineering', '.']
# ['Continuous', 'learning', 'and', 'adaptability', 'are', 'crucial', 'for', 'professionals', 'navigating', 'this', 'changing', 'landscape', '.']

# %%
for words in documents:
    word=wordpunct_tokenize(words)
    print(word)
# Out:
# ['Technology', 'has', 'transformed', 'the', 'way', 'people', 'live', ',', 'work', ',', 'and', 'communicate', '.']
# ['Over', 'the', 'past', 'two', 'decades', ',', 'digital', 'platforms', 'have', 'reshaped', 'industries', ',', 'enabling', 'businesses', 'to', 'operate', 'at', 'a', 'global', 'scale', '.']
# ['Remote', 'collaboration', 'tools', 'allow', 'teams', 'to', 'work', 'across', 'continents', ',', 'while', 'cloud', 'computing', 'provides', 'scalable', 'infrastructure', 'for', 'startups', 'and', 'enterprises', 'alike', '.']
# ['Artificial', 'intelligence', 'is', 'becoming', 'a', 'central', 'component', 'of', 'modern', 'systems', '.']
# ['From', 'recommendation', 'engines', 'to', 'autonomous', 'vehicles', ',', 'machine', 'learning', 'models', 'are', 'used', 'to', 'analyze', 'patterns', ',', 'make', 'predictions', ',', 'and', 'automate', 'decision', '-', 'making', 'processes', '.']
# ['As', 'these', 'systems', 'grow', 'more', 'advanced', ',', 'ethical', 'considerations', 'such', 'as', 'fairness', ',', 'transparency', ',', 'and', 'accountability', 'become', 'increasingly', 'important', '.']
# ['Education', 'is', 'also', 'evolving', 'rapidly', '.']
# ['Online', 'learning', 'platforms', 'provide', 'access', 'to', 'knowledge', 'for', 'millions', 'of', 'learners', 'worldwide', '.']
# ['Personalized', 'learning', 'systems', 'adapt', 'to', 'individual', 'student', 'needs', ',', 'offering', 'tailored', 'feedback', 'and', 'adaptive', 'assessments', '.']
# ['However', ',', 'access', 'to', 'reliable', 'internet', 'and', 'digital', 'devices', 'remains', 'uneven', ',', 'creating', 'disparities', 'in', 'educational', 'opportunities', '.']
# ['Climate', 'change', 'presents', 'one', 'of', 'the', 'most', 'pressing', 'challenges', 'of', 'our', 'time', '.']
# ['Governments', ',', 'corporations', ',', 'and', 'communities', 'are', 'investing', 'in', 'renewable', 'energy', 'solutions', ',', 'sustainable', 'agriculture', ',', 'and', 'carbon', 'reduction', 'strategies', '.']
# ['Innovation', 'in', 'battery', 'storage', ',', 'electric', 'vehicles', ',', 'and', 'smart', 'grids', 'plays', 'a', 'critical', 'role', 'in', 'reducing', 'greenhouse', 'gas', 'emissions', '.']
# ['Healthcare', 'is', 'benefiting', 'from', 'advances', 'in', 'biotechnology', 'and', 'data', 'science', '.']
# ['Wearable', 'devices', 'track', 'vital', 'signs', 'in', 'real', 'time', ',', 'enabling', 'proactive', 'health', 'monitoring', '.']
# ['Predictive', 'analytics', 'assists', 'physicians', 'in', 'diagnosing', 'diseases', 'earlier', 'and', 'developing', 'targeted', 'treatment', 'plans', '.']
# ['At', 'the', 'same', 'time', ',', 'data', 'privacy', 'and', 'regulatory', 'compliance', 'remain', 'essential', 'considerations', '.']
# ['Urbanization', 'continues', 'to', 'shape', 'economic', 'development', '.']
# ['Smart', 'cities', 'leverage', 'sensors', ',', 'IoT', 'networks', ',', 'and', 'data', 'analytics', 'to', 'improve', 'transportation', 'systems', ',', 'reduce', 'energy', 'consumption', ',', 'and', 'enhance', 'public', 'safety', '.']
# ['As', 'populations', 'grow', ',', 'sustainable', 'infrastructure', 'planning', 'becomes', 'increasingly', 'vital', '.']
# ['The', 'future', 'of', 'work', 'is', 'being', 'redefined', 'by', 'automation', 'and', 'digital', 'transformation', '.']
# ['While', 'some', 'roles', 'may', 'become', 'obsolete', ',', 'new', 'opportunities', 'emerge', 'in', 'fields', 'such', 'as', 'data', 'science', ',', 'cybersecurity', ',', 'and', 'AI', 'engineering', '.']
# ['Continuous', 'learning', 'and', 'adaptability', 'are', 'crucial', 'for', 'professionals', 'navigating', 'this', 'changing', 'landscape', '.']

# %%
for words in documents:
    word=TreebankWordTokenizer().tokenize(words)
    print(word)
# Out:
# ['Technology', 'has', 'transformed', 'the', 'way', 'people', 'live', ',', 'work', ',', 'and', 'communicate', '.']
# ['Over', 'the', 'past', 'two', 'decades', ',', 'digital', 'platforms', 'have', 'reshaped', 'industries', ',', 'enabling', 'businesses', 'to', 'operate', 'at', 'a', 'global', 'scale', '.']
# ['Remote', 'collaboration', 'tools', 'allow', 'teams', 'to', 'work', 'across', 'continents', ',', 'while', 'cloud', 'computing', 'provides', 'scalable', 'infrastructure', 'for', 'startups', 'and', 'enterprises', 'alike', '.']
# ['Artificial', 'intelligence', 'is', 'becoming', 'a', 'central', 'component', 'of', 'modern', 'systems', '.']
# ['From', 'recommendation', 'engines', 'to', 'autonomous', 'vehicles', ',', 'machine', 'learning', 'models', 'are', 'used', 'to', 'analyze', 'patterns', ',', 'make', 'predictions', ',', 'and', 'automate', 'decision-making', 'processes', '.']
# ['As', 'these', 'systems', 'grow', 'more', 'advanced', ',', 'ethical', 'considerations', 'such', 'as', 'fairness', ',', 'transparency', ',', 'and', 'accountability', 'become', 'increasingly', 'important', '.']
# ['Education', 'is', 'also', 'evolving', 'rapidly', '.']
# ['Online', 'learning', 'platforms', 'provide', 'access', 'to', 'knowledge', 'for', 'millions', 'of', 'learners', 'worldwide', '.']
# ['Personalized', 'learning', 'systems', 'adapt', 'to', 'individual', 'student', 'needs', ',', 'offering', 'tailored', 'feedback', 'and', 'adaptive', 'assessments', '.']
# ['However', ',', 'access', 'to', 'reliable', 'internet', 'and', 'digital', 'devices', 'remains', 'uneven', ',', 'creating', 'disparities', 'in', 'educational', 'opportunities', '.']
# ['Climate', 'change', 'presents', 'one', 'of', 'the', 'most', 'pressing', 'challenges', 'of', 'our', 'time', '.']
# ['Governments', ',', 'corporations', ',', 'and', 'communities', 'are', 'investing', 'in', 'renewable', 'energy', 'solutions', ',', 'sustainable', 'agriculture', ',', 'and', 'carbon', 'reduction', 'strategies', '.']
# ['Innovation', 'in', 'battery', 'storage', ',', 'electric', 'vehicles', ',', 'and', 'smart', 'grids', 'plays', 'a', 'critical', 'role', 'in', 'reducing', 'greenhouse', 'gas', 'emissions', '.']
# ['Healthcare', 'is', 'benefiting', 'from', 'advances', 'in', 'biotechnology', 'and', 'data', 'science', '.']
# ['Wearable', 'devices', 'track', 'vital', 'signs', 'in', 'real', 'time', ',', 'enabling', 'proactive', 'health', 'monitoring', '.']
# ['Predictive', 'analytics', 'assists', 'physicians', 'in', 'diagnosing', 'diseases', 'earlier', 'and', 'developing', 'targeted', 'treatment', 'plans', '.']
# ['At', 'the', 'same', 'time', ',', 'data', 'privacy', 'and', 'regulatory', 'compliance', 'remain', 'essential', 'considerations', '.']
# ['Urbanization', 'continues', 'to', 'shape', 'economic', 'development', '.']
# ['Smart', 'cities', 'leverage', 'sensors', ',', 'IoT', 'networks', ',', 'and', 'data', 'analytics', 'to', 'improve', 'transportation', 'systems', ',', 'reduce', 'energy', 'consumption', ',', 'and', 'enhance', 'public', 'safety', '.']
# ['As', 'populations', 'grow', ',', 'sustainable', 'infrastructure', 'planning', 'becomes', 'increasingly', 'vital', '.']
# ['The', 'future', 'of', 'work', 'is', 'being', 'redefined', 'by', 'automation', 'and', 'digital', 'transformation', '.']
# ['While', 'some', 'roles', 'may', 'become', 'obsolete', ',', 'new', 'opportunities', 'emerge', 'in', 'fields', 'such', 'as', 'data', 'science', ',', 'cybersecurity', ',', 'and', 'AI', 'engineering', '.']
# ['Continuous', 'learning', 'and', 'adaptability', 'are', 'crucial', 'for', 'professionals', 'navigating', 'this', 'changing', 'landscape', '.']
